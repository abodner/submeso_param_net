# %%
import cartopy 
import glob
import matplotlib.pyplot as plt
import os
import xarray as xr
import xgcm 
from fastjmd95 import jmd95numba 
import numpy as np
from scipy.stats import pearsonr
import torch.utils.data as Data
from torch.utils.data import DataLoader

BASE = '/scratch/ab10313/pleiades/'

PATH_LIST_PP = glob.glob(BASE+'*/preprcossed_data/')


import submeso_ml.data.dataset as dataset

# %%
features_for_plot = [r' $\overline{\nabla b}^z$', ' $\overline{f}$',' $\overline{H_{ML}}$',r' $\overline{\tau}$', ' $\overline{Q}$',' $\overline{H_{BL}}$',
                 ' $\overline{\delta}^z$', ' $\overline{\zeta}^z$', ' $\overline{\sigma}^z$', ' $\mathbb{Y}_{wb}$' ]

# %%
corr_mat_res = np.load('/scratch/ab10313/pleiades/trained_models/corr_map.npy')

# %% [markdown]
# ## correlation map between input and output features

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(10.5, 6), dpi=600)
plt.rcParams.update({'font.size': 10})
fig.tight_layout(pad=3.0)

plt.subplot(231)
plt.pcolor(corr_mat_res[0,:,:],cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10)
plt.yticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10);
plt.title('$1/12^o$')

plt.subplot(232)
plt.pcolor(corr_mat_res[1,:,:],cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10)
plt.yticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10);
plt.title('$1/8^o$')

plt.subplot(233)
plt.pcolor(corr_mat_res[2,:,:],cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10)
plt.yticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10);
plt.title('$1/4^o$')


plt.subplot(234)
plt.pcolor(corr_mat_res[3,:,:],cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10)
plt.yticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10);
plt.title('$1/2^o$')

plt.subplot(235)
plt.pcolor(corr_mat_res[4,:,:],cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10)
plt.yticks(np.arange(.5,10.5,1),features_for_plot,fontsize=10);
plt.title('$1^o$')

fig.delaxes(ax[1][2])

plt.savefig('./figures/inputs_output_corr_map.png')
